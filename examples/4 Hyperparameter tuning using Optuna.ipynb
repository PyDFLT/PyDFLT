# %%
import os
import sys

import numpy as np

path_to_project = os.path.dirname(os.path.abspath("")) + "/"
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("decision-focused-learning-codebase"))))

# %%
from src.utils.experiments import run, update_config
from src.utils.optuna import SearchSpaceConfig, create_study, save_progress
# Out:
# (CVXPY) Aug 21 03:30:32 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.14.6206). Expected < 9.12.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Aug 21 03:30:32 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.14.6206). Expected < 9.12.0. Please open a feature request on cvxpy to enable support for this version.')
# Auto-Sklearn cannot be imported.

# %% [markdown]
# ### Prepare config
#
# We first define a base config for which all parameters remain fixed

# %%
base_config = {
    "model": {"name": "cvxpy_knapsack_pyepo", "num_decisions": 10},
    "data": {"name": "knapsack_pyepo"},
    "problem": {"train_ratio": 0.7, "val_ratio": 0.15},
    "decision_maker": {"name": "differentiable"},
    "runner": {"num_epochs": 3, "use_wandb": False, "experiment_name": "test_tuning"},
}

# %% [markdown]
# ### Define trial
#
# To run hyperparameters tuning with Optuna, we need to define the 'objective' function that quantifies performance of each trial
# Essentially, this is the main function, that reads the parameters values from the search space and uses them for evaluation

# %%
def _run_trial(trial, seeds: list):
    assert len(seeds) > 0, "Provide at least one seed!"

    # Parse Optuna Trial to get a config of the values
    trial_config = search_space.get_trial_config(trial)

    # For more robust evaluation, we run each hyperparameter configuration for multiple seeds (same across different configurations)
    # Make sure to use different seeds for the experiments after
    per_seeds_results = []
    for seed in seeds:
        # Update config based on trial
        config = update_config(base_config=base_config, updates_config=trial_config)

        # Initialize all objects with the seed
        config["seed"] = seed
        for key in config:
            if isinstance(config[key], dict) and "seed" in config[key]:
                config[key]["seed"] = seed

        results = run(config, optuna_trial=trial)
        per_seeds_results.append(results)

    try:
        return np.mean(per_seeds_results)
    except optuna.TrialPruned:
        raise

# %% [markdown]
# ###Define search spaces

# %%
# To conduct a hyperparameter tuning experiment, we first need to define the search spaces
search_space = SearchSpaceConfig(path_to_project + "examples/hparams_search_spaces/test_search_config.yaml")
print(search_space.config)
# Out:
# {'decision_maker': {'learning_rate': {'type': 'float', 'low': 1e-05, 'high': 0.001, 'log': True}, 'batch_size': {'type': 'int', 'low': 1, 'high': 512, 'log': True}}}

# %% [markdown]
# ##Create pruner

# %%
# Creating a pruner will help pruning trials that are not promising
import optuna

pruner = optuna.pruners.MedianPruner(
    n_startup_trials=10,  # Number of trials to run before pruning
    n_warmup_steps=15,  # Number of epochs to wait before pruning
    interval_steps=1,  # Interval between pruning checks
    n_min_trials=1,  # Minimum trials required for pruning
)

# %%
# Specify study name and the folder where the results are stored
# A database.db file will be created in the folder OUTPUT_DIR
# While different problems/methods can be all inside the same database, it can be convenient to separate it by problem or method
STUDY_NAME = "test_study"  # Note that optuna will continue with an existing study if the study already exists
OUTPUT_DIR = "hparam_optimization_results/"  # Folder where the study database is stored (at OUTPUT_DIR/STUDY_NAME)
os.makedirs(f"{OUTPUT_DIR}/{STUDY_NAME}", exist_ok=True)  # Ensure that the folder exists
study = create_study(
    STUDY_NAME,
    storage_url=f"sqlite:///{OUTPUT_DIR}/{STUDY_NAME}/database.db",
    prunner=pruner,
)
# Out:
# Storage url: sqlite:///hparam_optimization_results//test_study/database.db
# [I 2025-08-21 15:30:56,381] Using an existing study with name 'test_study' instead of creating a new one.

# %%
# We can set up a dashboard that visualizes results when the study is running, opened in the background.
# Make sure to install the package optuna-dashboard.
# Alternatively open the dashboard through the terminal using:
# optuna-dashboard sqlite:///hparam_optimization_results//test_study//database.db --port=8889
import subprocess

port = "8889"
subprocess.Popen(
    [
        "optuna-dashboard",
        "sqlite:///hparam_optimization_results//test_study//database.db",
        "--port",
        port,
    ]
)

print(f"See dashboard here: http://localhost:{port}")
# Out:
# See dashboard here: http://localhost:8889

# %%
# Now we run the study
def objective_fn(trial):
    return _run_trial(trial, seeds=list(range(3)))


study.optimize(objective_fn, n_trials=3, timeout=None, catch=(Exception,), show_progress_bar=True)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3428
# validation/rel_regret_mean: 0.4783
# validation/mse_mean: 24.5923
# validation/x_mean: 0.1484
# validation/abs_regret_mean: 5.2566
# validation/objective_mean: 8.0268
# validation/c_mean: 4.4360
# Initial best validation metric (abs_regret): 5.2566070556640625
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Listening on http://127.0.0.1:8889/
# Hit Ctrl-C to quit.
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3428
# train/loss_mean: 6.7126
# validation/rel_regret_mean: 0.4783
# validation/mse_mean: 24.5923
# validation/x_mean: 0.1484
# train/abs_regret_mean: 6.7126
# validation/abs_regret_mean: 5.2566
# validation/objective_mean: 8.0268
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 324.5000
# validation/c_mean: 4.4360
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3439
# train/loss_mean: 6.7126
# validation/rel_regret_mean: 0.4793
# validation/mse_mean: 24.6950
# validation/x_mean: 0.1483
# train/abs_regret_mean: 6.7126
# validation/abs_regret_mean: 5.2652
# validation/objective_mean: 8.0182
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 324.5000
# validation/c_mean: 4.4455
# Validation evaluation (abs_regret): 5.273838043212891
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3439
# train/loss_mean: 6.8400
# validation/rel_regret_mean: 0.4793
# validation/mse_mean: 24.6950
# validation/x_mean: 0.1483
# train/abs_regret_mean: 6.8400
# validation/abs_regret_mean: 5.2652
# validation/objective_mean: 8.0182
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 537.0000
# validation/c_mean: 4.4455
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3441
# train/loss_mean: 6.8400
# validation/rel_regret_mean: 0.4796
# validation/mse_mean: 24.7436
# validation/x_mean: 0.1482
# train/abs_regret_mean: 6.8400
# validation/abs_regret_mean: 5.2750
# validation/objective_mean: 8.0085
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 537.0000
# validation/c_mean: 4.4499
# Validation evaluation (abs_regret): 5.294407367706299
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3441
# train/loss_mean: 6.8426
# validation/rel_regret_mean: 0.4796
# validation/mse_mean: 24.7436
# validation/x_mean: 0.1482
# train/abs_regret_mean: 6.8426
# validation/abs_regret_mean: 5.2750
# validation/objective_mean: 8.0085
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 4.4499
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3447
# train/loss_mean: 6.8426
# validation/rel_regret_mean: 0.4807
# validation/mse_mean: 24.7759
# validation/x_mean: 0.1480
# train/abs_regret_mean: 6.8426
# validation/abs_regret_mean: 5.2986
# validation/objective_mean: 7.9848
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 4.4527
# Validation evaluation (abs_regret): 5.369414806365967
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3447
# test/c_mean: 4.4390
# train/loss_mean: 6.8426
# test/mse_mean: 75.9043
# validation/rel_regret_mean: 0.4807
# validation/mse_mean: 24.7759
# validation/x_mean: 0.1480
# train/abs_regret_mean: 6.8426
# test/abs_regret_mean: 7.6448
# test/x_mean: 0.1487
# validation/abs_regret_mean: 5.2986
# test/sym_rel_regret_mean: 0.3602
# test/rel_regret_mean: 0.5022
# validation/objective_mean: 7.9848
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 4.4527
# test/objective_mean: 9.5520
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2746
# validation/rel_regret_mean: 0.4003
# validation/mse_mean: 51.8791
# validation/x_mean: 0.1435
# validation/abs_regret_mean: 4.5405
# validation/objective_mean: 8.8934
# validation/c_mean: 4.2424
# Initial best validation metric (abs_regret): 4.540495872497559
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2746
# train/loss_mean: 5.4386
# validation/rel_regret_mean: 0.4003
# validation/mse_mean: 51.8791
# validation/x_mean: 0.1435
# train/abs_regret_mean: 5.4386
# validation/abs_regret_mean: 4.5405
# validation/objective_mean: 8.8934
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 324.5000
# validation/c_mean: 4.2424
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2801
# train/loss_mean: 5.4386
# validation/rel_regret_mean: 0.4062
# validation/mse_mean: 51.9513
# validation/x_mean: 0.1460
# train/abs_regret_mean: 5.4386
# validation/abs_regret_mean: 4.6309
# validation/objective_mean: 8.8030
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 324.5000
# validation/c_mean: 4.2324
# Validation evaluation (abs_regret): 4.721228122711182
# Epoch: 2/3
# Problem mode set to: train
# /Users/noah/Documents/Python projects/decision-focused-learning-codebase/.venv/lib/python3.9/site-packages/optuna/trial/_trial.py:497: UserWarning: The reported value is ignored because this `step` 1 is already reported.
#   warnings.warn(
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2801
# train/loss_mean: 5.4740
# validation/rel_regret_mean: 0.4062
# validation/mse_mean: 51.9513
# validation/x_mean: 0.1460
# train/abs_regret_mean: 5.4740
# validation/abs_regret_mean: 4.6309
# validation/objective_mean: 8.8030
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 537.0000
# validation/c_mean: 4.2324
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2860
# train/loss_mean: 5.4740
# validation/rel_regret_mean: 0.4125
# validation/mse_mean: 52.0142
# validation/x_mean: 0.1473
# train/abs_regret_mean: 5.4740
# validation/abs_regret_mean: 4.7370
# validation/objective_mean: 8.6969
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 537.0000
# validation/c_mean: 4.2235
# Validation evaluation (abs_regret): 4.949247360229492
# Epoch: 3/3
# Problem mode set to: train
# /Users/noah/Documents/Python projects/decision-focused-learning-codebase/.venv/lib/python3.9/site-packages/optuna/trial/_trial.py:497: UserWarning: The reported value is ignored because this `step` 2 is already reported.
#   warnings.warn(
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2860
# train/loss_mean: 5.4677
# validation/rel_regret_mean: 0.4125
# validation/mse_mean: 52.0142
# validation/x_mean: 0.1473
# train/abs_regret_mean: 5.4677
# validation/abs_regret_mean: 4.7370
# validation/objective_mean: 8.6969
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 4.2235
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2909
# train/loss_mean: 5.4677
# validation/rel_regret_mean: 0.4182
# validation/mse_mean: 52.0539
# validation/x_mean: 0.1480
# train/abs_regret_mean: 5.4677
# validation/abs_regret_mean: 5.0010
# validation/objective_mean: 8.4328
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 4.2191
# Validation evaluation (abs_regret): 5.793196678161621
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2909
# test/c_mean: 4.2413
# train/loss_mean: 5.4677
# test/mse_mean: 69.7304
# validation/rel_regret_mean: 0.4182
# validation/mse_mean: 52.0539
# validation/x_mean: 0.1480
# train/abs_regret_mean: 5.4677
# test/abs_regret_mean: 6.3470
# test/x_mean: 0.1406
# validation/abs_regret_mean: 5.0010
# test/sym_rel_regret_mean: 0.3246
# test/rel_regret_mean: 0.4450
# validation/objective_mean: 8.4328
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 4.2191
# test/objective_mean: 10.2546
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# /Users/noah/Documents/Python projects/decision-focused-learning-codebase/.venv/lib/python3.9/site-packages/optuna/trial/_trial.py:497: UserWarning: The reported value is ignored because this `step` 3 is already reported.
#   warnings.warn(
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2612
# validation/rel_regret_mean: 0.3708
# validation/mse_mean: 57.6359
# validation/x_mean: 0.1763
# validation/abs_regret_mean: 8.5667
# validation/objective_mean: 9.5209
# validation/c_mean: 3.8630
# Initial best validation metric (abs_regret): 8.566689491271973
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2612
# train/loss_mean: 6.8853
# validation/rel_regret_mean: 0.3708
# validation/mse_mean: 57.6359
# validation/x_mean: 0.1763
# train/abs_regret_mean: 6.8853
# validation/abs_regret_mean: 8.5667
# validation/objective_mean: 9.5209
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 324.5000
# validation/c_mean: 3.8630
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2634
# train/loss_mean: 6.8853
# validation/rel_regret_mean: 0.3738
# validation/mse_mean: 57.7237
# validation/x_mean: 0.1760
# train/abs_regret_mean: 6.8853
# validation/abs_regret_mean: 8.5944
# validation/objective_mean: 9.4932
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 324.5000
# validation/c_mean: 3.8663
# Validation evaluation (abs_regret): 8.622026443481445
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2634
# train/loss_mean: 7.0228
# validation/rel_regret_mean: 0.3738
# validation/mse_mean: 57.7237
# validation/x_mean: 0.1760
# train/abs_regret_mean: 7.0228
# validation/abs_regret_mean: 8.5944
# validation/objective_mean: 9.4932
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 537.0000
# validation/c_mean: 3.8663
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2663
# train/loss_mean: 7.0228
# validation/rel_regret_mean: 0.3775
# validation/mse_mean: 57.5289
# validation/x_mean: 0.1758
# train/abs_regret_mean: 7.0228
# validation/abs_regret_mean: 8.5613
# validation/objective_mean: 9.5262
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 537.0000
# validation/c_mean: 3.8845
# Validation evaluation (abs_regret): 8.495308876037598
# New best validation evaluation (abs_regret): 8.495308876037598 (was 8.566689491271973)
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2663
# train/loss_mean: 7.1527
# validation/rel_regret_mean: 0.3775
# validation/mse_mean: 57.5289
# validation/x_mean: 0.1758
# train/abs_regret_mean: 7.1527
# validation/abs_regret_mean: 8.5613
# validation/objective_mean: 9.5262
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 3.8845
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2728
# train/loss_mean: 7.1527
# validation/rel_regret_mean: 0.3851
# validation/mse_mean: 57.3835
# validation/x_mean: 0.1757
# train/abs_regret_mean: 7.1527
# validation/abs_regret_mean: 8.6368
# validation/objective_mean: 9.4508
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 3.8993
# Validation evaluation (abs_regret): 8.863086700439453
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2728
# test/c_mean: 3.9195
# train/loss_mean: 7.1527
# test/mse_mean: 41.3598
# validation/rel_regret_mean: 0.3851
# validation/mse_mean: 57.3835
# validation/x_mean: 0.1757
# train/abs_regret_mean: 7.1527
# test/abs_regret_mean: 7.1609
# test/x_mean: 0.1752
# validation/abs_regret_mean: 8.6368
# test/sym_rel_regret_mean: 0.3002
# test/rel_regret_mean: 0.4240
# validation/objective_mean: 9.4508
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 749.5000
# validation/c_mean: 3.8993
# test/objective_mean: 8.6575
# [I 2025-07-09 13:36:16,981] Trial 5 finished with value: 6.097470760345459 and parameters: {'learning_rate': 0.0002255434766383487, 'batch_size': 108}. Best is trial 1 with value: 4.9115142822265625.
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1499
# validation/x_mean: 0.1833
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# validation/c_mean: 4.5261
# Initial best validation metric (abs_regret): 3.7248222827911377
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# train/loss_mean: 4.5361
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1499
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.5361
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 368.0000
# validation/c_mean: 4.5261
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# train/loss_mean: 4.5361
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1409
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.5361
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 368.0000
# validation/c_mean: 4.5359
# Validation evaluation (abs_regret): 3.7248222827911377
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# train/loss_mean: 4.3033
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1409
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.3033
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 580.5000
# validation/c_mean: 4.5359
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# train/loss_mean: 4.3033
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1221
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.3033
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 580.5000
# validation/c_mean: 4.5382
# Validation evaluation (abs_regret): 3.7248222827911377
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# train/loss_mean: 4.3492
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1221
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.3492
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 4.5382
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# train/loss_mean: 4.3492
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1010
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.3492
# validation/abs_regret_mean: 3.7248
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 4.5330
# Validation evaluation (abs_regret): 3.7248222827911377
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2190
# test/c_mean: 4.5505
# train/loss_mean: 4.3492
# test/mse_mean: 33.0140
# validation/rel_regret_mean: 0.3285
# validation/mse_mean: 24.1010
# validation/x_mean: 0.1833
# train/abs_regret_mean: 4.3492
# test/abs_regret_mean: 4.5673
# test/x_mean: 0.1833
# validation/abs_regret_mean: 3.7248
# test/sym_rel_regret_mean: 0.2471
# test/rel_regret_mean: 0.3585
# validation/objective_mean: 8.3536
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 4.5330
# test/objective_mean: 9.6802
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2628
# validation/rel_regret_mean: 0.3857
# validation/mse_mean: 19.0730
# validation/x_mean: 0.1576
# validation/abs_regret_mean: 3.9963
# validation/objective_mean: 7.1871
# validation/c_mean: 4.5514
# Initial best validation metric (abs_regret): 3.9962756633758545
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2628
# train/loss_mean: 5.3998
# validation/rel_regret_mean: 0.3857
# validation/mse_mean: 19.0730
# validation/x_mean: 0.1576
# train/abs_regret_mean: 5.3998
# validation/abs_regret_mean: 3.9963
# validation/objective_mean: 7.1871
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 368.0000
# validation/c_mean: 4.5514
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2626
# train/loss_mean: 5.3998
# validation/rel_regret_mean: 0.3846
# validation/mse_mean: 19.0583
# validation/x_mean: 0.1580
# train/abs_regret_mean: 5.3998
# validation/abs_regret_mean: 3.9848
# validation/objective_mean: 7.1986
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 368.0000
# validation/c_mean: 4.5451
# Validation evaluation (abs_regret): 3.973315954208374
# New best validation evaluation (abs_regret): 3.973315954208374 (was 3.9962756633758545)
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2626
# train/loss_mean: 5.4968
# validation/rel_regret_mean: 0.3846
# validation/mse_mean: 19.0583
# validation/x_mean: 0.1580
# train/abs_regret_mean: 5.4968
# validation/abs_regret_mean: 3.9848
# validation/objective_mean: 7.1986
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 580.5000
# validation/c_mean: 4.5451
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2606
# train/loss_mean: 5.4968
# validation/rel_regret_mean: 0.3813
# validation/mse_mean: 19.0188
# validation/x_mean: 0.1586
# train/abs_regret_mean: 5.4968
# validation/abs_regret_mean: 3.9737
# validation/objective_mean: 7.2097
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 580.5000
# validation/c_mean: 4.5377
# Validation evaluation (abs_regret): 3.951491355895996
# New best validation evaluation (abs_regret): 3.951491355895996 (was 3.973315954208374)
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2606
# train/loss_mean: 5.5000
# validation/rel_regret_mean: 0.3813
# validation/mse_mean: 19.0188
# validation/x_mean: 0.1586
# train/abs_regret_mean: 5.5000
# validation/abs_regret_mean: 3.9737
# validation/objective_mean: 7.2097
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 4.5377
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2594
# train/loss_mean: 5.5000
# validation/rel_regret_mean: 0.3792
# validation/mse_mean: 18.9801
# validation/x_mean: 0.1590
# train/abs_regret_mean: 5.5000
# validation/abs_regret_mean: 3.9658
# validation/objective_mean: 7.2176
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 4.5316
# Validation evaluation (abs_regret): 3.9420344829559326
# New best validation evaluation (abs_regret): 3.9420344829559326 (was 3.951491355895996)
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2594
# test/c_mean: 4.5473
# train/loss_mean: 5.5000
# test/mse_mean: 28.4742
# validation/rel_regret_mean: 0.3792
# validation/mse_mean: 18.9801
# validation/x_mean: 0.1590
# train/abs_regret_mean: 5.5000
# test/abs_regret_mean: 4.6664
# test/x_mean: 0.1587
# validation/abs_regret_mean: 3.9658
# test/sym_rel_regret_mean: 0.2591
# test/rel_regret_mean: 0.3780
# validation/objective_mean: 7.2176
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 4.5316
# test/objective_mean: 8.9958
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3718
# validation/rel_regret_mean: 0.5042
# validation/mse_mean: 55.5153
# validation/x_mean: 0.1495
# validation/abs_regret_mean: 9.0649
# validation/objective_mean: 6.4288
# validation/c_mean: 3.8922
# Initial best validation metric (abs_regret): 9.064933776855469
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3718
# train/loss_mean: 7.4225
# validation/rel_regret_mean: 0.5042
# validation/mse_mean: 55.5153
# validation/x_mean: 0.1495
# train/abs_regret_mean: 7.4225
# validation/abs_regret_mean: 9.0649
# validation/objective_mean: 6.4288
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 368.0000
# validation/c_mean: 3.8922
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3580
# train/loss_mean: 7.4225
# validation/rel_regret_mean: 0.4888
# validation/mse_mean: 55.1786
# validation/x_mean: 0.1513
# train/abs_regret_mean: 7.4225
# validation/abs_regret_mean: 8.7936
# validation/objective_mean: 6.7001
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 368.0000
# validation/c_mean: 3.9015
# Validation evaluation (abs_regret): 8.522250175476074
# New best validation evaluation (abs_regret): 8.522250175476074 (was 9.064933776855469)
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3580
# train/loss_mean: 7.3580
# validation/rel_regret_mean: 0.4888
# validation/mse_mean: 55.1786
# validation/x_mean: 0.1513
# train/abs_regret_mean: 7.3580
# validation/abs_regret_mean: 8.7936
# validation/objective_mean: 6.7001
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 580.5000
# validation/c_mean: 3.9015
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3489
# train/loss_mean: 7.3580
# validation/rel_regret_mean: 0.4807
# validation/mse_mean: 54.9386
# validation/x_mean: 0.1526
# train/abs_regret_mean: 7.3580
# validation/abs_regret_mean: 8.4298
# validation/objective_mean: 7.0640
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 580.5000
# validation/c_mean: 3.9071
# Validation evaluation (abs_regret): 7.702149868011475
# New best validation evaluation (abs_regret): 7.702149868011475 (was 8.522250175476074)
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3489
# train/loss_mean: 7.2140
# validation/rel_regret_mean: 0.4807
# validation/mse_mean: 54.9386
# validation/x_mean: 0.1526
# train/abs_regret_mean: 7.2140
# validation/abs_regret_mean: 8.4298
# validation/objective_mean: 7.0640
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 3.9071
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3410
# train/loss_mean: 7.2140
# validation/rel_regret_mean: 0.4751
# validation/mse_mean: 54.6791
# validation/x_mean: 0.1536
# train/abs_regret_mean: 7.2140
# validation/abs_regret_mean: 8.1445
# validation/objective_mean: 7.3492
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 3.9154
# Validation evaluation (abs_regret): 7.288846015930176
# New best validation evaluation (abs_regret): 7.288846015930176 (was 7.702149868011475)
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3410
# test/c_mean: 3.9454
# train/loss_mean: 7.2140
# test/mse_mean: 27.6804
# validation/rel_regret_mean: 0.4751
# validation/mse_mean: 54.6791
# validation/x_mean: 0.1536
# train/abs_regret_mean: 7.2140
# test/abs_regret_mean: 6.2374
# test/x_mean: 0.1574
# validation/abs_regret_mean: 8.1445
# test/sym_rel_regret_mean: 0.3178
# test/rel_regret_mean: 0.4450
# validation/objective_mean: 7.3492
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 793.0000
# validation/c_mean: 3.9154
# test/objective_mean: 6.1862
# [I 2025-07-09 13:36:28,769] Trial 6 finished with value: 4.985234260559082 and parameters: {'learning_rate': 0.0003542522914954905, 'batch_size': 236}. Best is trial 1 with value: 4.9115142822265625.
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9986
# validation/x_mean: 0.1736
# validation/abs_regret_mean: 4.0396
# validation/objective_mean: 8.3490
# validation/c_mean: 4.5711
# Initial best validation metric (abs_regret): 4.039603233337402
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# train/loss_mean: 4.7455
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9986
# validation/x_mean: 0.1736
# train/abs_regret_mean: 4.7455
# validation/abs_regret_mean: 4.0396
# validation/objective_mean: 8.3490
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 364.6667
# validation/c_mean: 4.5711
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# train/loss_mean: 4.7455
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9923
# validation/x_mean: 0.1736
# train/abs_regret_mean: 4.7455
# validation/abs_regret_mean: 4.0396
# validation/objective_mean: 8.3490
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 364.6667
# validation/c_mean: 4.5706
# Validation evaluation (abs_regret): 4.039603233337402
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# train/loss_mean: 4.4979
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9923
# validation/x_mean: 0.1736
# train/abs_regret_mean: 4.4979
# validation/abs_regret_mean: 4.0396
# validation/objective_mean: 8.3490
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 577.1667
# validation/c_mean: 4.5706
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# train/loss_mean: 4.4979
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9863
# validation/x_mean: 0.1736
# train/abs_regret_mean: 4.4979
# validation/abs_regret_mean: 4.0396
# validation/objective_mean: 8.3490
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 577.1667
# validation/c_mean: 4.5702
# Validation evaluation (abs_regret): 4.039603233337402
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# train/loss_mean: 4.5519
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9863
# validation/x_mean: 0.1736
# train/abs_regret_mean: 4.5519
# validation/abs_regret_mean: 4.0396
# validation/objective_mean: 8.3490
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 4.5702
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# train/loss_mean: 4.5519
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9818
# validation/x_mean: 0.1735
# train/abs_regret_mean: 4.5519
# validation/abs_regret_mean: 4.0390
# validation/objective_mean: 8.3496
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 4.5699
# Validation evaluation (abs_regret): 4.0370941162109375
# New best validation evaluation (abs_regret): 4.0370941162109375 (was 4.039603233337402)
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2513
# test/c_mean: 4.5679
# train/loss_mean: 4.5519
# test/mse_mean: 54.4307
# validation/rel_regret_mean: 0.3748
# validation/mse_mean: 22.9818
# validation/x_mean: 0.1735
# train/abs_regret_mean: 4.5519
# test/abs_regret_mean: 5.2179
# test/x_mean: 0.1732
# validation/abs_regret_mean: 4.0390
# test/sym_rel_regret_mean: 0.2983
# test/rel_regret_mean: 0.4261
# validation/objective_mean: 8.3496
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 4.5699
# test/objective_mean: 10.3128
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.4024
# validation/rel_regret_mean: 0.5437
# validation/mse_mean: 41.5048
# validation/x_mean: 0.1296
# validation/abs_regret_mean: 8.0483
# validation/objective_mean: 8.0343
# validation/c_mean: 4.2550
# Initial best validation metric (abs_regret): 8.048286437988281
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.4024
# train/loss_mean: 7.1335
# validation/rel_regret_mean: 0.5437
# validation/mse_mean: 41.5048
# validation/x_mean: 0.1296
# train/abs_regret_mean: 7.1335
# validation/abs_regret_mean: 8.0483
# validation/objective_mean: 8.0343
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 364.6667
# validation/c_mean: 4.2550
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.4001
# train/loss_mean: 7.1335
# validation/rel_regret_mean: 0.5407
# validation/mse_mean: 41.5042
# validation/x_mean: 0.1298
# train/abs_regret_mean: 7.1335
# validation/abs_regret_mean: 8.0358
# validation/objective_mean: 8.0467
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 364.6667
# validation/c_mean: 4.2543
# Validation evaluation (abs_regret): 8.023397445678711
# New best validation evaluation (abs_regret): 8.023397445678711 (was 8.048286437988281)
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.4001
# train/loss_mean: 6.4051
# validation/rel_regret_mean: 0.5407
# validation/mse_mean: 41.5042
# validation/x_mean: 0.1298
# train/abs_regret_mean: 6.4051
# validation/abs_regret_mean: 8.0358
# validation/objective_mean: 8.0467
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 577.1667
# validation/c_mean: 4.2543
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3994
# train/loss_mean: 6.4051
# validation/rel_regret_mean: 0.5398
# validation/mse_mean: 41.5035
# validation/x_mean: 0.1298
# train/abs_regret_mean: 6.4051
# validation/abs_regret_mean: 8.0317
# validation/objective_mean: 8.0509
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 577.1667
# validation/c_mean: 4.2540
# Validation evaluation (abs_regret): 8.023397445678711
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3994
# train/loss_mean: 6.0250
# validation/rel_regret_mean: 0.5398
# validation/mse_mean: 41.5035
# validation/x_mean: 0.1298
# train/abs_regret_mean: 6.0250
# validation/abs_regret_mean: 8.0317
# validation/objective_mean: 8.0509
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 4.2540
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3990
# train/loss_mean: 6.0250
# validation/rel_regret_mean: 0.5393
# validation/mse_mean: 41.5019
# validation/x_mean: 0.1298
# train/abs_regret_mean: 6.0250
# validation/abs_regret_mean: 8.0296
# validation/objective_mean: 8.0529
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 4.2538
# Validation evaluation (abs_regret): 8.023397445678711
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.3990
# test/c_mean: 4.2474
# train/loss_mean: 6.0250
# test/mse_mean: 32.5515
# validation/rel_regret_mean: 0.5393
# validation/mse_mean: 41.5019
# validation/x_mean: 0.1298
# train/abs_regret_mean: 6.0250
# test/abs_regret_mean: 6.5721
# test/x_mean: 0.1297
# validation/abs_regret_mean: 8.0296
# test/sym_rel_regret_mean: 0.3452
# test/rel_regret_mean: 0.4817
# validation/objective_mean: 8.0529
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 4.2538
# test/objective_mean: 7.5363
# Generating data using knapsack_pyepo
# Shape of weights: (1, 10), values: (500, 10), features: (500, 5).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=350, Validation=75, Test=75
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/3: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2470
# validation/rel_regret_mean: 0.3557
# validation/mse_mean: 43.0883
# validation/x_mean: 0.2001
# validation/abs_regret_mean: 7.0042
# validation/objective_mean: 8.0290
# validation/c_mean: 3.8533
# Initial best validation metric (abs_regret): 7.004159450531006
# Starting training...
# Epoch: 1/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2470
# train/loss_mean: 5.1952
# validation/rel_regret_mean: 0.3557
# validation/mse_mean: 43.0883
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.1952
# validation/abs_regret_mean: 7.0042
# validation/objective_mean: 8.0290
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 364.6667
# validation/c_mean: 3.8533
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2466
# train/loss_mean: 5.1952
# validation/rel_regret_mean: 0.3553
# validation/mse_mean: 43.0557
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.1952
# validation/abs_regret_mean: 6.9925
# validation/objective_mean: 8.0407
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 364.6667
# validation/c_mean: 3.8551
# Validation evaluation (abs_regret): 6.9807586669921875
# New best validation evaluation (abs_regret): 6.9807586669921875 (was 7.004159450531006)
# Epoch: 2/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2466
# train/loss_mean: 5.0963
# validation/rel_regret_mean: 0.3553
# validation/mse_mean: 43.0557
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.0963
# validation/abs_regret_mean: 6.9925
# validation/objective_mean: 8.0407
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 577.1667
# validation/c_mean: 3.8551
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2464
# train/loss_mean: 5.0963
# validation/rel_regret_mean: 0.3551
# validation/mse_mean: 43.0335
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.0963
# validation/abs_regret_mean: 6.9886
# validation/objective_mean: 8.0446
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 577.1667
# validation/c_mean: 3.8564
# Validation evaluation (abs_regret): 6.9807586669921875
# Epoch: 3/3
# Problem mode set to: train
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2464
# train/loss_mean: 5.0042
# validation/rel_regret_mean: 0.3551
# validation/mse_mean: 43.0335
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.0042
# validation/abs_regret_mean: 6.9886
# validation/objective_mean: 8.0446
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 3.8564
# Problem mode set to: validation
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2464
# train/loss_mean: 5.0042
# validation/rel_regret_mean: 0.3551
# validation/mse_mean: 43.0148
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.0042
# validation/abs_regret_mean: 6.9866
# validation/objective_mean: 8.0465
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 3.8576
# Validation evaluation (abs_regret): 6.9807586669921875
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/sym_rel_regret_mean: 0.2464
# test/c_mean: 3.8685
# train/loss_mean: 5.0042
# test/mse_mean: 33.7980
# validation/rel_regret_mean: 0.3551
# validation/mse_mean: 43.0148
# validation/x_mean: 0.2001
# train/abs_regret_mean: 5.0042
# test/abs_regret_mean: 5.3826
# test/x_mean: 0.2000
# validation/abs_regret_mean: 6.9866
# test/sym_rel_regret_mean: 0.2383
# test/rel_regret_mean: 0.3459
# validation/objective_mean: 8.0465
# train/grad_norm_mean: 0.0000
# train/solver_calls_mean: 789.6667
# validation/c_mean: 3.8576
# test/objective_mean: 7.4019
# [I 2025-07-09 13:36:40,253] Trial 7 finished with value: 6.347083568572998 and parameters: {'learning_rate': 1.376049702033979e-05, 'batch_size': 173}. Best is trial 1 with value: 4.9115142822265625.

# %%
# The dashboard summarizes the results. Alternatively results can be retrieved as follows.
import optuna

path = f"sqlite:///{OUTPUT_DIR}/{STUDY_NAME}/database.db"
studies = optuna.study.get_all_study_summaries(storage=path)

for study_summary in studies:
    study_name = study_summary.study_name
    study = optuna.load_study(study_name=study_name, storage=path)

    print(
        f"Results study: {study_name}\n"
        f"Completed trials: {len(study.trials)}\n"
        f"Best value: {study.best_value:.4f}\n"
        f"Best parameters: {study.best_params}"
    )
# Out:
# Results study: test_study
# Completed trials: 8
# Best value: 4.9115
# Best parameters: {'learning_rate': 0.0006497345283948292, 'batch_size': 215}

# %%
# We save the best configuration to a YAML file
save_progress(study, search_space, OUTPUT_DIR)
# Out:
# Best configuration saved to hparam_optimization_results/best_config.yaml
