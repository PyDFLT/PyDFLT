# %% [markdown]
# In this notebook, we show how to learn a predictive model using decision-focused learning approaches SPO+ [1] and PFYL [2] on the shortest path problem (using PyEPO [3]).

# %%
import os
import sys

path_to_project = os.path.dirname(os.path.abspath("")) + "/"
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("decision-focused-learning-codebase"))))
print(path_to_project)

# %%
from src.concrete_models.grbpy_shortest_path import ShortestPath
from src.decision_makers.differentiable_decision_maker import (
    DifferentiableDecisionMaker,
)
from src.generate_data_functions.generate_data_shortestpath import gen_data_shortestpath
from src.problem import Problem
from src.runner import Runner
# Out:
# /Users/noah/Documents/Python projects/decision-focused-learning-codebase/
# Auto-Sklearn cannot be imported.
# /Users/noah/Documents/Python projects/decision-focused-learning-codebase/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# The goal in the shortest path problem is to move from start (NW) to end (SE) (TODO: image?) in a 2D grid. In the predict and optimize setting we have here, the costs of each edge is uncertain but correlated with some (feature) values. Our aim is to learn a predictor that predicts costs such that the decision quality (the chosen path) has minimal costs on average.
#
# (Some details on problem specifics)

# %% [markdown]
# We first construct the `OptimizationModel`

# %%
model = ShortestPath(grid=(10, 10))
print(f"For a grid of size {model.grid}, there are {len(model.arcs)} arcs.")
print(f"The uncertain parameters we have to predict for this problem are {model.param_to_predict_names} with size {model.param_to_predict_shapes}.")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-05-16
# For a grid of size (10, 10), there are 180 arcs.
# The uncertain parameters we have to predict for this problem are ['c'] with size {'c': (180,)}.

# %% [markdown]
# We can use a data generation script to generate our data. This data generation script could be replaced by reading the data from a file.

# %%
data_dict = gen_data_shortestpath(
    seed=5,
    num_data=500,
    num_features=5,
    grid=(10, 10),
    polynomial_degree=5,
    noise_width=0.5,
)
print(f"The data dictionary contains the following: {list(data_dict.keys())}")
for key in data_dict.keys():
    print(f"The shape of {key} is {data_dict[key].shape}")
# Out:
# Shape of values: (500, 180), features: (500, 5).
# The data dictionary contains the following: ['c', 'features']
# The shape of c is (500, 180)
# The shape of features is (500, 5)

# %% [markdown]
# We are making use of a problem class that contains the optimization model and the data, which is split into a training set, a validation set and a test set. *The compute_optimal_decisions and compute_optimal_objectives parameters are used to pre-compute optimal decisions and objectives, which is practical for most DFL approaches, but unwanted if the data is too large and there is not enough memory.*

# %%
problem = Problem(
    data_dict=data_dict,
    opt_model=model,
    train_ratio=0.4,
    val_ratio=0.2,
    compute_optimal_decisions=True,
    compute_optimal_objectives=True,
)
print(f"The size of the training set equals {problem.train_size}, which corresponds to the number of training indices {len(problem.train_indices)}.")
# Out:
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=200, Validation=100, Test=200
# The size of the training set equals 200, which corresponds to the number of training indices 200.

# %% [markdown]
# Now we are almost set to run a DFL algorithm. In the general predict and optimize setting, our aim is to make the best decision given feature values. This is why we use the `DecisionMaker` object, which includes a predictive model. Let's first do some prediction-focused learning as a baseline. For this we use the `DifferentiableDecisionMaker`.

# %%
predictor_kwargs = {
    "size": 256,
    "num_hidden_layers": 2,
    "activation": "leaky_relu",
    "output_activation": "identity",
}
predictor_str = "MLP"
loss_function_str = "mse"
decision_maker = DifferentiableDecisionMaker(
    problem=problem,
    learning_rate=0.005,
    batch_size=32,
    device_str="cpu",
    loss_function_str=loss_function_str,
    predictor_str=predictor_str,
    predictor_kwargs=predictor_kwargs,
)
# Out:
# Problem mode set to: train
# Problem mode set to: train

# %% [markdown]
# We need use the `Runner` class to run our DFL algorithm

# %%
runner = Runner(decision_maker, num_epochs=5, use_wandb=False)
runner.run()
# Out:
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 10.7414
# validation/sym_rel_regret_mean: 0.3425
# validation/abs_regret_mean: 4.8216
# validation/rel_regret_mean: 1.3711
# validation/c_mean: 0.7929
# validation/x_mean: 0.1000
# Initial best validation metric (abs_regret): 4.821632385253906
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 10.7414
# validation/sym_rel_regret_mean: 0.3425
# validation/abs_regret_mean: 4.8216
# validation/rel_regret_mean: 1.3711
# train/solver_calls_mean: 100.0000
# validation/c_mean: 0.7929
# train/loss_mean: 0.7084
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4628
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 8.9880
# validation/sym_rel_regret_mean: 0.2295
# validation/abs_regret_mean: 3.0683
# validation/rel_regret_mean: 0.8306
# train/solver_calls_mean: 100.0000
# validation/c_mean: 0.6754
# train/loss_mean: 0.7084
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4628
# Validation evaluation (abs_regret): 1.314879298210144
# New best validation evaluation (abs_regret): 1.314879298210144 (was 4.821632385253906)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 8.9880
# validation/sym_rel_regret_mean: 0.2295
# validation/abs_regret_mean: 3.0683
# validation/rel_regret_mean: 0.8306
# train/solver_calls_mean: 150.0000
# validation/c_mean: 0.6754
# train/loss_mean: 0.5476
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.5324
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 8.2619
# validation/sym_rel_regret_mean: 0.1881
# validation/abs_regret_mean: 2.3421
# validation/rel_regret_mean: 0.6562
# train/solver_calls_mean: 150.0000
# validation/c_mean: 0.7191
# train/loss_mean: 0.5476
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.5324
# Validation evaluation (abs_regret): 0.8898392915725708
# New best validation evaluation (abs_regret): 0.8898392915725708 (was 1.314879298210144)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 8.2619
# validation/sym_rel_regret_mean: 0.1881
# validation/abs_regret_mean: 2.3421
# validation/rel_regret_mean: 0.6562
# train/solver_calls_mean: 200.0000
# validation/c_mean: 0.7191
# train/loss_mean: 0.4452
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4756
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 7.9149
# validation/sym_rel_regret_mean: 0.1671
# validation/abs_regret_mean: 1.9952
# validation/rel_regret_mean: 0.5631
# train/solver_calls_mean: 200.0000
# validation/c_mean: 0.7200
# train/loss_mean: 0.4452
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4756
# Validation evaluation (abs_regret): 0.9543757438659668
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 7.9149
# validation/sym_rel_regret_mean: 0.1671
# validation/abs_regret_mean: 1.9952
# validation/rel_regret_mean: 0.5631
# train/solver_calls_mean: 250.0000
# validation/c_mean: 0.7200
# train/loss_mean: 0.3944
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4722
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 7.7021
# validation/sym_rel_regret_mean: 0.1530
# validation/abs_regret_mean: 1.7823
# validation/rel_regret_mean: 0.4981
# train/solver_calls_mean: 250.0000
# validation/c_mean: 0.6928
# train/loss_mean: 0.3944
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4722
# Validation evaluation (abs_regret): 0.9310173988342285
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 7.7021
# validation/sym_rel_regret_mean: 0.1530
# validation/abs_regret_mean: 1.7823
# validation/rel_regret_mean: 0.4981
# train/solver_calls_mean: 300.0000
# validation/c_mean: 0.6928
# train/loss_mean: 0.3576
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4544
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 7.5382
# validation/sym_rel_regret_mean: 0.1408
# validation/abs_regret_mean: 1.6184
# validation/rel_regret_mean: 0.4490
# train/solver_calls_mean: 300.0000
# validation/c_mean: 0.6997
# train/loss_mean: 0.3576
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4544
# Validation evaluation (abs_regret): 0.7988115549087524
# New best validation evaluation (abs_regret): 0.7988115549087524 (was 0.8898392915725708)
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 7.5382
# validation/sym_rel_regret_mean: 0.1408
# validation/abs_regret_mean: 1.6184
# test/sym_rel_regret_mean: 0.0967
# validation/rel_regret_mean: 0.4490
# test/x_mean: 0.1000
# train/solver_calls_mean: 300.0000
# test/objective_mean: 7.5822
# test/c_mean: 0.8111
# test/abs_regret_mean: 0.9821
# test/rel_regret_mean: 0.2422
# validation/c_mean: 0.6997
# train/loss_mean: 0.3576
# validation/x_mean: 0.1000
# train/grad_norm_mean: 0.4544
# 0.79881155

# %% [markdown]
# Now let's run SPO+ [1]

# %%
loss_function_str = "SPOPlus"
decision_maker = DifferentiableDecisionMaker(
    problem=problem,
    learning_rate=0.005,
    batch_size=32,
    device_str="cpu",
    loss_function_str=loss_function_str,
    predictor_str=predictor_str,
    predictor_kwargs=predictor_kwargs,
)
runner = Runner(decision_maker, num_epochs=5, use_wandb=False)
runner.run()
# Out:
# Problem mode set to: train
# Problem mode set to: train
# Num of cores: 1
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 10.6073
# validation/sym_rel_regret_mean: 0.3438
# validation/abs_regret_mean: 4.6875
# validation/rel_regret_mean: 1.3681
# validation/c_mean: 0.7934
# validation/x_mean: 0.1000
# Initial best validation metric (abs_regret): 4.687525272369385
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 10.6073
# validation/sym_rel_regret_mean: 0.3438
# validation/abs_regret_mean: 4.6875
# train/rel_regret_mean: 0.4497
# validation/rel_regret_mean: 1.3681
# train/sym_rel_regret_mean: 0.1490
# train/solver_calls_mean: 224.5714
# train/objective_mean: 9.5865
# train/abs_regret_mean: 2.3322
# validation/c_mean: 0.7934
# train/loss_mean: 10.8837
# validation/x_mean: 0.1000
# train/grad_norm_mean: 14.7431
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 8.7504
# validation/sym_rel_regret_mean: 0.2129
# validation/abs_regret_mean: 2.8307
# train/rel_regret_mean: 0.4497
# validation/rel_regret_mean: 0.7851
# train/sym_rel_regret_mean: 0.1490
# train/solver_calls_mean: 224.5714
# train/objective_mean: 9.5865
# train/abs_regret_mean: 2.3322
# validation/c_mean: 0.7974
# train/loss_mean: 10.8837
# validation/x_mean: 0.1000
# train/grad_norm_mean: 14.7431
# Validation evaluation (abs_regret): 0.9738179445266724
# New best validation evaluation (abs_regret): 0.9738179445266724 (was 4.687525272369385)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 8.7504
# validation/sym_rel_regret_mean: 0.2129
# validation/abs_regret_mean: 2.8307
# train/rel_regret_mean: 0.3145
# validation/rel_regret_mean: 0.7851
# train/sym_rel_regret_mean: 0.1121
# train/solver_calls_mean: 374.5714
# train/objective_mean: 8.9770
# train/abs_regret_mean: 1.6247
# validation/c_mean: 0.7974
# train/loss_mean: 8.3748
# validation/x_mean: 0.1000
# train/grad_norm_mean: 15.3476
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 8.0415
# validation/sym_rel_regret_mean: 0.1625
# validation/abs_regret_mean: 2.1218
# train/rel_regret_mean: 0.3145
# validation/rel_regret_mean: 0.5702
# train/sym_rel_regret_mean: 0.1121
# train/solver_calls_mean: 374.5714
# train/objective_mean: 8.9770
# train/abs_regret_mean: 1.6247
# validation/c_mean: 0.8041
# train/loss_mean: 8.3748
# validation/x_mean: 0.1000
# train/grad_norm_mean: 15.3476
# Validation evaluation (abs_regret): 0.7039470672607422
# New best validation evaluation (abs_regret): 0.7039470672607422 (was 0.9738179445266724)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 8.0415
# validation/sym_rel_regret_mean: 0.1625
# validation/abs_regret_mean: 2.1218
# train/rel_regret_mean: 0.2516
# validation/rel_regret_mean: 0.5702
# train/sym_rel_regret_mean: 0.0933
# train/solver_calls_mean: 524.5714
# train/objective_mean: 8.6102
# train/abs_regret_mean: 1.3113
# validation/c_mean: 0.8041
# train/loss_mean: 7.0329
# validation/x_mean: 0.1000
# train/grad_norm_mean: 14.6064
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 7.6653
# validation/sym_rel_regret_mean: 0.1357
# validation/abs_regret_mean: 1.7455
# train/rel_regret_mean: 0.2516
# validation/rel_regret_mean: 0.4586
# train/sym_rel_regret_mean: 0.0933
# train/solver_calls_mean: 524.5714
# train/objective_mean: 8.6102
# train/abs_regret_mean: 1.3113
# validation/c_mean: 0.8096
# train/loss_mean: 7.0329
# validation/x_mean: 0.1000
# train/grad_norm_mean: 14.6064
# Validation evaluation (abs_regret): 0.6167367696762085
# New best validation evaluation (abs_regret): 0.6167367696762085 (was 0.7039470672607422)
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 7.6653
# validation/sym_rel_regret_mean: 0.1357
# validation/abs_regret_mean: 1.7455
# train/rel_regret_mean: 0.2173
# validation/rel_regret_mean: 0.4586
# train/sym_rel_regret_mean: 0.0827
# train/solver_calls_mean: 674.5714
# train/objective_mean: 8.3432
# train/abs_regret_mean: 1.1242
# validation/c_mean: 0.8096
# train/loss_mean: 6.0449
# validation/x_mean: 0.1000
# train/grad_norm_mean: 13.4711
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 7.4391
# validation/sym_rel_regret_mean: 0.1209
# validation/abs_regret_mean: 1.5193
# train/rel_regret_mean: 0.2173
# validation/rel_regret_mean: 0.3956
# train/sym_rel_regret_mean: 0.0827
# train/solver_calls_mean: 674.5714
# train/objective_mean: 8.3432
# train/abs_regret_mean: 1.1242
# validation/c_mean: 0.8108
# train/loss_mean: 6.0449
# validation/x_mean: 0.1000
# train/grad_norm_mean: 13.4711
# Validation evaluation (abs_regret): 0.6144726872444153
# New best validation evaluation (abs_regret): 0.6144726872444153 (was 0.6167367696762085)
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 7.4391
# validation/sym_rel_regret_mean: 0.1209
# validation/abs_regret_mean: 1.5193
# train/rel_regret_mean: 0.1921
# validation/rel_regret_mean: 0.3956
# train/sym_rel_regret_mean: 0.0744
# train/solver_calls_mean: 824.5714
# train/objective_mean: 8.2725
# train/abs_regret_mean: 1.0077
# validation/c_mean: 0.8108
# train/loss_mean: 5.3656
# validation/x_mean: 0.1000
# train/grad_norm_mean: 12.5294
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 7.2834
# validation/sym_rel_regret_mean: 0.1092
# validation/abs_regret_mean: 1.3637
# train/rel_regret_mean: 0.1921
# validation/rel_regret_mean: 0.3483
# train/sym_rel_regret_mean: 0.0744
# train/solver_calls_mean: 824.5714
# train/objective_mean: 8.2725
# train/abs_regret_mean: 1.0077
# validation/c_mean: 0.8108
# train/loss_mean: 5.3656
# validation/x_mean: 0.1000
# train/grad_norm_mean: 12.5294
# Validation evaluation (abs_regret): 0.5855843424797058
# New best validation evaluation (abs_regret): 0.5855843424797058 (was 0.6144726872444153)
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 7.2834
# validation/sym_rel_regret_mean: 0.1092
# validation/abs_regret_mean: 1.3637
# test/sym_rel_regret_mean: 0.0628
# validation/rel_regret_mean: 0.3483
# train/sym_rel_regret_mean: 0.0744
# test/abs_regret_mean: 0.8200
# train/rel_regret_mean: 0.1921
# test/x_mean: 0.1000
# train/solver_calls_mean: 824.5714
# test/objective_mean: 7.4201
# validation/c_mean: 0.8108
# train/loss_mean: 5.3656
# train/objective_mean: 8.2725
# train/abs_regret_mean: 1.0077
# test/c_mean: 0.8225
# test/rel_regret_mean: 0.1418
# validation/x_mean: 0.1000
# train/grad_norm_mean: 12.5294
# 0.58558434

# %% [markdown]
# There is a wide variety of DFL algorithms for optimization models with uncertainty linear in the objective, since we use PyEPO [2] under the hood for these type of models. They are specfied as the *loss_function_str*

# %%
decision_maker.allowed_losses
# Out:
# ['mse',
#  'objective',
#  'regret',
#  'SPOPlus',
#  'perturbedOpt',
#  'perturbedFenchelYoung',
#  'implicitMLE',
#  'blackboxOpt',
#  'negativeIdentity',
#  'smooth']

# %% [markdown]
# To more easily run full-fledged experiments, the run() function can be used. For clear and concise use of different settings you can use configs as yaml files (using dictionaries is also possible).

# %%
import yaml

from src.utils.experiments import run

sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(""))))


for seed in range(5):
    yaml_dir = "examples/linear_objective_config.yml"
    config = yaml.safe_load(open(path_to_project + yaml_dir))
    config["seed"] = seed
    run(config)
# Out:
# Generating data using shortestpath_5x5
# Shape of values: (250, 40), features: (250, 5).
# Features normalized (mean 0, std 1).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=20, Validation=20, Test=210
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 5.2171
# validation/sym_rel_regret_mean: 0.2091
# validation/abs_regret_mean: 1.9413
# validation/rel_regret_mean: 0.5920
# validation/c_mean: 0.6214
# validation/x_mean: 0.2000
# Initial best validation metric (rel_regret): 0.5919764041900635
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 5.2171
# validation/sym_rel_regret_mean: 0.2091
# validation/abs_regret_mean: 1.9413
# validation/rel_regret_mean: 0.5920
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6214
# train/loss_mean: 0.4980
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2127
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.7526
# validation/sym_rel_regret_mean: 0.1694
# validation/abs_regret_mean: 1.4767
# validation/rel_regret_mean: 0.4640
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6114
# train/loss_mean: 0.4980
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2127
# Validation evaluation (rel_regret): 0.3359263837337494
# New best validation evaluation (rel_regret): 0.3359263837337494 (was 0.5919764041900635)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.7526
# validation/sym_rel_regret_mean: 0.1694
# validation/abs_regret_mean: 1.4767
# validation/rel_regret_mean: 0.4640
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6114
# train/loss_mean: 0.4370
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2078
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.4820
# validation/sym_rel_regret_mean: 0.1464
# validation/abs_regret_mean: 1.2061
# validation/rel_regret_mean: 0.3947
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6006
# train/loss_mean: 0.4370
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2078
# Validation evaluation (rel_regret): 0.25610798597335815
# New best validation evaluation (rel_regret): 0.25610798597335815 (was 0.3359263837337494)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.4820
# validation/sym_rel_regret_mean: 0.1464
# validation/abs_regret_mean: 1.2061
# validation/rel_regret_mean: 0.3947
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.6006
# train/loss_mean: 0.3836
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2184
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3452
# validation/sym_rel_regret_mean: 0.1342
# validation/abs_regret_mean: 1.0694
# validation/rel_regret_mean: 0.3584
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.6021
# train/loss_mean: 0.3836
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2184
# Validation evaluation (rel_regret): 0.2497539073228836
# New best validation evaluation (rel_regret): 0.2497539073228836 (was 0.25610798597335815)
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.3452
# validation/sym_rel_regret_mean: 0.1342
# validation/abs_regret_mean: 1.0694
# validation/rel_regret_mean: 0.3584
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.6021
# train/loss_mean: 0.3342
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2122
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3155
# validation/sym_rel_regret_mean: 0.1305
# validation/abs_regret_mean: 1.0397
# validation/rel_regret_mean: 0.3472
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.6147
# train/loss_mean: 0.3342
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2122
# Validation evaluation (rel_regret): 0.3021501302719116
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.3155
# validation/sym_rel_regret_mean: 0.1305
# validation/abs_regret_mean: 1.0397
# validation/rel_regret_mean: 0.3472
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.6147
# train/loss_mean: 0.2933
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2115
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3254
# validation/sym_rel_regret_mean: 0.1306
# validation/abs_regret_mean: 1.0496
# validation/rel_regret_mean: 0.3478
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.6256
# train/loss_mean: 0.2933
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2115
# Validation evaluation (rel_regret): 0.35110363364219666
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 4.3254
# validation/sym_rel_regret_mean: 0.1306
# validation/abs_regret_mean: 1.0496
# test/sym_rel_regret_mean: 0.1327
# validation/rel_regret_mean: 0.3478
# test/x_mean: 0.2000
# train/solver_calls_mean: 60.0000
# test/objective_mean: 4.3944
# test/c_mean: 0.6485
# test/abs_regret_mean: 0.9389
# test/rel_regret_mean: 0.3740
# validation/c_mean: 0.6256
# train/loss_mean: 0.2933
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2115
# Generating data using shortestpath_5x5
# Shape of values: (250, 40), features: (250, 5).
# Features normalized (mean 0, std 1).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=20, Validation=20, Test=210
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 6.0077
# validation/sym_rel_regret_mean: 0.2838
# validation/abs_regret_mean: 2.7319
# validation/rel_regret_mean: 0.8756
# validation/c_mean: 0.6261
# validation/x_mean: 0.2000
# Initial best validation metric (rel_regret): 0.8755598068237305
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 6.0077
# validation/sym_rel_regret_mean: 0.2838
# validation/abs_regret_mean: 2.7319
# validation/rel_regret_mean: 0.8756
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6261
# train/loss_mean: 0.4943
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2155
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 5.1477
# validation/sym_rel_regret_mean: 0.2189
# validation/abs_regret_mean: 1.8719
# validation/rel_regret_mean: 0.6400
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6140
# train/loss_mean: 0.4943
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2155
# Validation evaluation (rel_regret): 0.40450143814086914
# New best validation evaluation (rel_regret): 0.40450143814086914 (was 0.8755598068237305)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 5.1477
# validation/sym_rel_regret_mean: 0.2189
# validation/abs_regret_mean: 1.8719
# validation/rel_regret_mean: 0.6400
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6140
# train/loss_mean: 0.4336
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2143
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.8406
# validation/sym_rel_regret_mean: 0.1851
# validation/abs_regret_mean: 1.5648
# validation/rel_regret_mean: 0.5236
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6036
# train/loss_mean: 0.4336
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2143
# Validation evaluation (rel_regret): 0.29077669978141785
# New best validation evaluation (rel_regret): 0.29077669978141785 (was 0.40450143814086914)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.8406
# validation/sym_rel_regret_mean: 0.1851
# validation/abs_regret_mean: 1.5648
# validation/rel_regret_mean: 0.5236
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.6036
# train/loss_mean: 0.3768
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2225
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.6871
# validation/sym_rel_regret_mean: 0.1672
# validation/abs_regret_mean: 1.4113
# validation/rel_regret_mean: 0.4624
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.5994
# train/loss_mean: 0.3768
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2225
# Validation evaluation (rel_regret): 0.2789188623428345
# New best validation evaluation (rel_regret): 0.2789188623428345 (was 0.29077669978141785)
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.6871
# validation/sym_rel_regret_mean: 0.1672
# validation/abs_regret_mean: 1.4113
# validation/rel_regret_mean: 0.4624
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.5994
# train/loss_mean: 0.3247
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2219
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.5713
# validation/sym_rel_regret_mean: 0.1538
# validation/abs_regret_mean: 1.2954
# validation/rel_regret_mean: 0.4194
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.6127
# train/loss_mean: 0.3247
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2219
# Validation evaluation (rel_regret): 0.2472110539674759
# New best validation evaluation (rel_regret): 0.2472110539674759 (was 0.2789188623428345)
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.5713
# validation/sym_rel_regret_mean: 0.1538
# validation/abs_regret_mean: 1.2954
# validation/rel_regret_mean: 0.4194
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.6127
# train/loss_mean: 0.2831
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2164
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.4913
# validation/sym_rel_regret_mean: 0.1445
# validation/abs_regret_mean: 1.2155
# validation/rel_regret_mean: 0.3903
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.6263
# train/loss_mean: 0.2831
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2164
# Validation evaluation (rel_regret): 0.2447890043258667
# New best validation evaluation (rel_regret): 0.2447890043258667 (was 0.2472110539674759)
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 4.4913
# validation/sym_rel_regret_mean: 0.1445
# validation/abs_regret_mean: 1.2155
# test/sym_rel_regret_mean: 0.0964
# validation/rel_regret_mean: 0.3903
# test/x_mean: 0.2000
# train/solver_calls_mean: 60.0000
# test/objective_mean: 4.1079
# test/c_mean: 0.7899
# test/abs_regret_mean: 0.6524
# test/rel_regret_mean: 0.2590
# validation/c_mean: 0.6263
# train/loss_mean: 0.2831
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2164
# Generating data using shortestpath_5x5
# Shape of values: (250, 40), features: (250, 5).
# Features normalized (mean 0, std 1).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=20, Validation=20, Test=210
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.9026
# validation/sym_rel_regret_mean: 0.2199
# validation/abs_regret_mean: 1.6268
# validation/rel_regret_mean: 0.6336
# validation/c_mean: 0.6278
# validation/x_mean: 0.2000
# Initial best validation metric (rel_regret): 0.6335907578468323
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.9026
# validation/sym_rel_regret_mean: 0.2199
# validation/abs_regret_mean: 1.6268
# validation/rel_regret_mean: 0.6336
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6278
# train/loss_mean: 0.4906
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1992
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.6034
# validation/sym_rel_regret_mean: 0.1927
# validation/abs_regret_mean: 1.3276
# validation/rel_regret_mean: 0.5415
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6063
# train/loss_mean: 0.4906
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1992
# Validation evaluation (rel_regret): 0.44946885108947754
# New best validation evaluation (rel_regret): 0.44946885108947754 (was 0.6335907578468323)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.6034
# validation/sym_rel_regret_mean: 0.1927
# validation/abs_regret_mean: 1.3276
# validation/rel_regret_mean: 0.5415
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6063
# train/loss_mean: 0.4342
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1910
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.4253
# validation/sym_rel_regret_mean: 0.1685
# validation/abs_regret_mean: 1.1495
# validation/rel_regret_mean: 0.4624
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.5880
# train/loss_mean: 0.4342
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1910
# Validation evaluation (rel_regret): 0.30405670404434204
# New best validation evaluation (rel_regret): 0.30405670404434204 (was 0.44946885108947754)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.4253
# validation/sym_rel_regret_mean: 0.1685
# validation/abs_regret_mean: 1.1495
# validation/rel_regret_mean: 0.4624
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.5880
# train/loss_mean: 0.3853
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1993
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3028
# validation/sym_rel_regret_mean: 0.1523
# validation/abs_regret_mean: 1.0270
# validation/rel_regret_mean: 0.4111
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.5810
# train/loss_mean: 0.3853
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1993
# Validation evaluation (rel_regret): 0.2572987377643585
# New best validation evaluation (rel_regret): 0.2572987377643585 (was 0.30405670404434204)
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.3028
# validation/sym_rel_regret_mean: 0.1523
# validation/abs_regret_mean: 1.0270
# validation/rel_regret_mean: 0.4111
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.5810
# train/loss_mean: 0.3405
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2017
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.2140
# validation/sym_rel_regret_mean: 0.1374
# validation/abs_regret_mean: 0.9382
# validation/rel_regret_mean: 0.3656
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.5872
# train/loss_mean: 0.3405
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2017
# Validation evaluation (rel_regret): 0.18371817469596863
# New best validation evaluation (rel_regret): 0.18371817469596863 (was 0.2572987377643585)
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.2140
# validation/sym_rel_regret_mean: 0.1374
# validation/abs_regret_mean: 0.9382
# validation/rel_regret_mean: 0.3656
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.5872
# train/loss_mean: 0.3014
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2000
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.1435
# validation/sym_rel_regret_mean: 0.1286
# validation/abs_regret_mean: 0.8677
# validation/rel_regret_mean: 0.3404
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.5943
# train/loss_mean: 0.3014
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2000
# Validation evaluation (rel_regret): 0.21415221691131592
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 4.1435
# validation/sym_rel_regret_mean: 0.1286
# validation/abs_regret_mean: 0.8677
# test/sym_rel_regret_mean: 0.1071
# validation/rel_regret_mean: 0.3404
# test/x_mean: 0.2000
# train/solver_calls_mean: 60.0000
# test/objective_mean: 4.2729
# test/c_mean: 0.6870
# test/abs_regret_mean: 0.8174
# test/rel_regret_mean: 0.2902
# validation/c_mean: 0.5943
# train/loss_mean: 0.3014
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2000
# Generating data using shortestpath_5x5
# Shape of values: (250, 40), features: (250, 5).
# Features normalized (mean 0, std 1).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=20, Validation=20, Test=210
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.6924
# validation/sym_rel_regret_mean: 0.1934
# validation/abs_regret_mean: 1.4166
# validation/rel_regret_mean: 0.5621
# validation/c_mean: 0.6049
# validation/x_mean: 0.2000
# Initial best validation metric (rel_regret): 0.5620678663253784
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.6924
# validation/sym_rel_regret_mean: 0.1934
# validation/abs_regret_mean: 1.4166
# validation/rel_regret_mean: 0.5621
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6049
# train/loss_mean: 0.4929
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2009
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.4697
# validation/sym_rel_regret_mean: 0.1726
# validation/abs_regret_mean: 1.1939
# validation/rel_regret_mean: 0.4827
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.5880
# train/loss_mean: 0.4929
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2009
# Validation evaluation (rel_regret): 0.40329137444496155
# New best validation evaluation (rel_regret): 0.40329137444496155 (was 0.5620678663253784)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.4697
# validation/sym_rel_regret_mean: 0.1726
# validation/abs_regret_mean: 1.1939
# validation/rel_regret_mean: 0.4827
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.5880
# train/loss_mean: 0.4403
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1992
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3567
# validation/sym_rel_regret_mean: 0.1565
# validation/abs_regret_mean: 1.0809
# validation/rel_regret_mean: 0.4275
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.5757
# train/loss_mean: 0.4403
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.1992
# Validation evaluation (rel_regret): 0.3170815706253052
# New best validation evaluation (rel_regret): 0.3170815706253052 (was 0.40329137444496155)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.3567
# validation/sym_rel_regret_mean: 0.1565
# validation/abs_regret_mean: 1.0809
# validation/rel_regret_mean: 0.4275
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.5757
# train/loss_mean: 0.3913
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2103
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.2393
# validation/sym_rel_regret_mean: 0.1375
# validation/abs_regret_mean: 0.9635
# validation/rel_regret_mean: 0.3674
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.5745
# train/loss_mean: 0.3913
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2103
# Validation evaluation (rel_regret): 0.18721535801887512
# New best validation evaluation (rel_regret): 0.18721535801887512 (was 0.3170815706253052)
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.2393
# validation/sym_rel_regret_mean: 0.1375
# validation/abs_regret_mean: 0.9635
# validation/rel_regret_mean: 0.3674
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.5745
# train/loss_mean: 0.3443
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2104
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.2403
# validation/sym_rel_regret_mean: 0.1332
# validation/abs_regret_mean: 0.9645
# validation/rel_regret_mean: 0.3517
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.5858
# train/loss_mean: 0.3443
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2104
# Validation evaluation (rel_regret): 0.2888273596763611
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.2403
# validation/sym_rel_regret_mean: 0.1332
# validation/abs_regret_mean: 0.9645
# validation/rel_regret_mean: 0.3517
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.5858
# train/loss_mean: 0.3043
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2094
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.2472
# validation/sym_rel_regret_mean: 0.1303
# validation/abs_regret_mean: 0.9714
# validation/rel_regret_mean: 0.3423
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.5988
# train/loss_mean: 0.3043
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2094
# Validation evaluation (rel_regret): 0.2950436472892761
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 4.2472
# validation/sym_rel_regret_mean: 0.1303
# validation/abs_regret_mean: 0.9714
# test/sym_rel_regret_mean: 0.1223
# validation/rel_regret_mean: 0.3423
# test/x_mean: 0.2000
# train/solver_calls_mean: 60.0000
# test/objective_mean: 4.3614
# test/c_mean: 0.6182
# test/abs_regret_mean: 0.9059
# test/rel_regret_mean: 0.3336
# validation/c_mean: 0.5988
# train/loss_mean: 0.3043
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2094
# Generating data using shortestpath_5x5
# Shape of values: (250, 40), features: (250, 5).
# Features normalized (mean 0, std 1).
# Computing optimal decisions for the entire dataset...
# Optimal decisions computed and added to dataset.
# Computing optimal objectives for the entire dataset...
# Optimal objectives computed and added to dataset.
# Shuffling indices before splitting...
# Dataset split completed: Train=20, Validation=20, Test=210
# Problem mode set to: train
# Problem mode set to: train
# Epoch 0/5: Starting initial validation...
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 5.1322
# validation/sym_rel_regret_mean: 0.2386
# validation/abs_regret_mean: 1.8564
# validation/rel_regret_mean: 0.6965
# validation/c_mean: 0.6313
# validation/x_mean: 0.2000
# Initial best validation metric (rel_regret): 0.6964796781539917
# Starting training...
# Epoch: 1/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 5.1322
# validation/sym_rel_regret_mean: 0.2386
# validation/abs_regret_mean: 1.8564
# validation/rel_regret_mean: 0.6965
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6313
# train/loss_mean: 0.4889
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2134
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.7232
# validation/sym_rel_regret_mean: 0.1885
# validation/abs_regret_mean: 1.4474
# validation/rel_regret_mean: 0.5296
# train/solver_calls_mean: 20.0000
# validation/c_mean: 0.6162
# train/loss_mean: 0.4889
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2134
# Validation evaluation (rel_regret): 0.3626941442489624
# New best validation evaluation (rel_regret): 0.3626941442489624 (was 0.6964796781539917)
# Epoch: 2/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.7232
# validation/sym_rel_regret_mean: 0.1885
# validation/abs_regret_mean: 1.4474
# validation/rel_regret_mean: 0.5296
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6162
# train/loss_mean: 0.4327
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2141
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.4838
# validation/sym_rel_regret_mean: 0.1585
# validation/abs_regret_mean: 1.2079
# validation/rel_regret_mean: 0.4321
# train/solver_calls_mean: 30.0000
# validation/c_mean: 0.6102
# train/loss_mean: 0.4327
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2141
# Validation evaluation (rel_regret): 0.23725247383117676
# New best validation evaluation (rel_regret): 0.23725247383117676 (was 0.3626941442489624)
# Epoch: 3/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.4838
# validation/sym_rel_regret_mean: 0.1585
# validation/abs_regret_mean: 1.2079
# validation/rel_regret_mean: 0.4321
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.6102
# train/loss_mean: 0.3813
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2223
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3909
# validation/sym_rel_regret_mean: 0.1453
# validation/abs_regret_mean: 1.1150
# validation/rel_regret_mean: 0.3890
# train/solver_calls_mean: 40.0000
# validation/c_mean: 0.6155
# train/loss_mean: 0.3813
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2223
# Validation evaluation (rel_regret): 0.25940829515457153
# Epoch: 4/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.3909
# validation/sym_rel_regret_mean: 0.1453
# validation/abs_regret_mean: 1.1150
# validation/rel_regret_mean: 0.3890
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.6155
# train/loss_mean: 0.3329
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2180
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3596
# validation/sym_rel_regret_mean: 0.1382
# validation/abs_regret_mean: 1.0838
# validation/rel_regret_mean: 0.3656
# train/solver_calls_mean: 50.0000
# validation/c_mean: 0.6260
# train/loss_mean: 0.3329
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2180
# Validation evaluation (rel_regret): 0.27227121591567993
# Epoch: 5/5
# Problem mode set to: train
# Epoch Results:
# validation/objective_mean: 4.3596
# validation/sym_rel_regret_mean: 0.1382
# validation/abs_regret_mean: 1.0838
# validation/rel_regret_mean: 0.3656
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.6260
# train/loss_mean: 0.2919
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2142
# Problem mode set to: validation
# Epoch Results:
# validation/objective_mean: 4.3412
# validation/sym_rel_regret_mean: 0.1349
# validation/abs_regret_mean: 1.0654
# validation/rel_regret_mean: 0.3559
# train/solver_calls_mean: 60.0000
# validation/c_mean: 0.6352
# train/loss_mean: 0.2919
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2142
# Validation evaluation (rel_regret): 0.30735230445861816
# Training finished. Evaluating on the test set...
# Problem mode set to: test
# Epoch Results:
# validation/objective_mean: 4.3412
# validation/sym_rel_regret_mean: 0.1349
# validation/abs_regret_mean: 1.0654
# test/sym_rel_regret_mean: 0.1148
# validation/rel_regret_mean: 0.3559
# test/x_mean: 0.2000
# train/solver_calls_mean: 60.0000
# test/objective_mean: 4.2342
# test/c_mean: 0.6116
# test/abs_regret_mean: 0.7787
# test/rel_regret_mean: 0.2959
# validation/c_mean: 0.6352
# train/loss_mean: 0.2919
# validation/x_mean: 0.2000
# train/grad_norm_mean: 0.2142
